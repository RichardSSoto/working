# %% [markdown]
# ## Ejercicios
#
# Responde las siguientes preguntas

# %% [markdown]
# ** ¿Qué es 7 elevado a la 4?**

# %%
# Out:
# 2401

# %% [markdown]
# ** Separe el string:**
#
#     s = "Hi there Sam!"
#
# **en una lista. **

# %%
# Out:
# ['Hi', 'there', 'dad!']

# %% [markdown]
# ** Dadas las variables:**
#
#     planet = "Earth"
#     diameter = 12742
#
# ** Usar .format() para imprimir el siguiente string: **
#
#     The diameter of Earth is 12742 kilometers.

# %%
planet = "Earth"
diameter = 12742

# %%
# Out:
# The diameter of Earth is 12742 kilometers.

# %% [markdown]
# ** Dada esta lista anidada, use la indexación para tomar la palabra "hello"" **

# %%
lst = [1,2,[3,4],[5,[100,200,['hello']],23,11],1,7]

# %%
# Out:
# 'hello'

# %% [markdown]
# ** Dado este diccionario anidado, SLECCIONE la palabra "hello". **

# %%
d = {'k1':[1,2,3,{'tricky':['oh','man','inception',{'target':[1,2,3,'hello']}]}]}

# %%
# Out:
# 'hello'

# %% [markdown]
# ** ¿cuál es la diferencia entre una tupla y una lista? **

# %%
# Tupla es inmutable

# %% [markdown]
# ** Cree una función que tome el dominio del sitio web de correo electrónico de una cadena de la forma: **
#
#     user@domain.com
#
# **Por ejemplo, pasando "user@domain.com" debe retornar: domain.com**

# %%
domainGet('user@domain.com')
# Out:
# 'domain.com'

# %% [markdown]
# ** Cree una función básica que devuelva True si la palabra 'perro' está contenida en la cadena de entrada. Tener en cuenta las mayúsculas. **

# %%
findPerro('hay algún perro')
# Out:
# True

# %% [markdown]
# ** Cree una función que cuente la cantidad de veces que la palabra "perro" aparece en una cadena. Nuevamente ignore los casos extremos. **

# %%
countPerro('Este perro corre más rápido que este otro perro')
# Out:
# 2

# %% [markdown]
# ** Obtenga una posción de la cadena**

# %%
seq = ['sopa','perro','salado','gato','genial']

# %%
# Out:
# ['sopa', 'salado']

# %% [markdown]
# ** Denis está contigo en un proyecto grupal para el curso de Programación.
# Ustedes deben dibujar un rectángulo con Python para la presentación final.
# El profesor les avisó que, para tener buena nota, tienen que hacer un rectángulo que no sea tan sencillo. Para ello deciden separarse el trabajo, uno programa
# y el otro piensa como hacerlo especial. Al día siguiente, Denis te muestra un rectángulo que tiene esta forma: **
#
# <figure>
# <center>
# <img src='data:image/png;base64,...' />
# <figcaption>Image Caption</figcaption></center>
# </figure>

# %% [markdown]
# Ella ha decidido crear un rectángulo especial llenándolo de letras. Te explica que ha utilizado el par de coordenadas i, j para identificar cada celda del
# rectángulo, empezando desde 0, 0. Para poder llenar cada celda se tienen 2 letras a elegir, una letra base y otra letra especial. Utilizando las reglas, se
# decide cuál letra va en cada celda dependiendo de su posición i, j. Al terminar su explicación, te da un papel con dichas reglas:
#
# * Para empezar a construir el rectángulo necesitas estas 5 partes: longitud, altura, 1 letra base, 1 letra especial y 1 valor determinante.
# * Longitud y altura siempre tienen un valor mayor que 0 y nunca tendrán el mismo valor.
# * El valor determinante es igual al valor absoluto de la resta entre longitud y altura.
# * La regla para definir qué letra va en cada posición es:
# – Si i + j es múltiplo del valor determinante, entonces en esa posición i, j va una letra especial, en caso contrario, va una letra base.
# * Se tiene que retornar un string que represente la forma del rectángulo.
# Para ello pueden concatenar un string letra por letra y crear un salto de linea concatenando el caracter especial "\n".
#
# Ejemplo
#
# Input:
# * Longitud = 6
# * Altura = 4
# * LetraBase = ’O’
# * LetraEspecial = ’L’
#
# Output:
#
# "LOLOLO\nOLOLOL\nLOLOLO\nOLOLOL"
#
# Lo que equivale a:
#
# LOLOLO
#
# OLOLOL
#
# LOLOLO
#
# OLOLOL

# %% [markdown]
#  Evalua listas
# Desarrolle un programa que permita leer como dato un número entero positivo mayor a cero y el programa realice lo siguiente:
# * Forme una lista con números aleatorios cuyo rango de valores sea desde 0 al 9. La lista tendrá tantos n´umeros como lo indica el dato de entrada.
# * Imprima la lista generada
# * Forme una nueva lista, formada por sublistas las cuales son el resultado de dividir
# la lista original es sublistas cada vez que se encuentra el numero 0. Es decir el 0 actuará como un delimitador.
# * Note que el numeo 0, actua como un separador y no incluye en las sublistas.
#
# EJMEPLO:
#
# Numero de elementos :23
#
# [6 , 3 , 3 , 8, 9 , 3 , 0 , 5 , 4 , 5 , 7 , 0 , 5 , 8 , 0 , 7 , 7 , 2 , 6 , 2,
# 3 , 7 , 7]
#
#
# [[6 , 3 , 3 , 8, 9 , 3] , [5 , 4 , 5 , 7] , [5 , 8] , [7 , 7 , 2 , 6 , 2 ,
# 3 , 7 , 7]]

# %%
from numpy import random
random.randint(10)
# Out:
# 7
