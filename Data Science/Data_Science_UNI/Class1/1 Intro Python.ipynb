# %% [markdown]
# #BÁSICO

# %% [markdown]
# ##NÚMEROS

# %%
1*3
# Out:
# 3

# %%
1/2
# Out:
# 0.5

# %%
2**3
# Out:
# 8

# %%
184+4
# Out:
# 188

# %% [markdown]
# ##ASIGNACIONES

# %%
X=3

# %%
X
# Out:
# 3

# %%
type(X)
# Out:
# int

# %%
y=2.
type(y)
# Out:
# float

# %%
z=x+y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4293a5baa16b> in <module>()
# ----> 1 z=x+y
#
# NameError: name 'x' is not defined

# %%
Z=X+y

# %%
x=1
y=4
z=x+y

# %%
z
# Out:
# 5

# %% [markdown]
# ##PRINT

# %%
x=3

# %%
x='hola'

# %%
x
# Out:
# 'hola'

# %%
print(x)
# Out:
# hola

# %%
y=' mundo'

# %%
z=x+y

# %%
print(z)
# Out:
# hola mundo

# %%
print(x,y)
# Out:
# hola  mundo

# %%
num=12

# %%
print(num,x)
# Out:
# 12 hola

# %%
print('mi numero es: ', num, 'mi casa esta en:  ', y)
# Out:
# mi numero es:  12 mi casa esta en:    mundo

# %%
my_list=['a','b','c']

# %%
my_list
# Out:
# ['a', 'b', 'c']

# %%
my_list.append('d')

# %%
my_list[1]
# Out:
# 'b'

# %%
my_list[-1]
# Out:
# 'd'

# %%
my_list[:]
# Out:
# ['a', 'b', 'c', 'd']

# %%
my_list[0:]
# Out:
# ['a', 'b', 'c', 'd']

# %%
len(my_list)
# Out:
# 4

# %%
my_list=['a','b','c',['d','f',['a']]]

# %%
my_list[-1][-1][0]
# Out:
# 'a'

# %%
print(my_list[-1][-1][0])
# Out:
# a
